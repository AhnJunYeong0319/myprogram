# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:42:59
# [12, 6, 11]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:42:59
# [2, 9, 18]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:42:59
# [11, 15, 2]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:42:59
# [19, 11, 10]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:43:00
# [5, 9, 19]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:43:00
# [2, 7, 1]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:43:00
# [20, 14, 16]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()

x
# Out:
# Current Time = 01:43:00
# [6, 11, 7]
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# ...

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()
# Out:
# Current Time = 01:43:00
# [17, 5, 14]

# %%
from datetime import datetime
import random
import pandas as pd

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =", current_time)

winner_index = random.sample([i for i in range(1,22)],3)
print(winner_index)

x = pd.read_csv('./먹튀검증사이트 인식 설문조사2.csv/먹튀검증사이트 인식 설문조사2.csv')
x = x.iloc[:,5]
x = pd.Series(x)
x.dropna(how=all,inplace=True)
x = x.reset_index()
# Out:
# Current Time = 01:43:00
# [20, 6, 5]

# %%
x.iloc[[20,6,5],1]
# Out:
# 20    이현주 010-6888-5587
# 6         010 8692 9398
# 5       김하연 01088157041
# Name: 5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다)., dtype: object

# %%
x
# Out:
#     index  \
# 0       0
# 1       1
# 2       3
# 3       5
# 4       6
# 5       7
# 6       8
# 7       9
# 8      13
# 9      14
# 10     15
# 11     16
# 12     17
# 13     18
# 14     20
# 15     21
# 16     23
# 17     25
# 18     26
# 19     27
# 20     28
#
#    5. 본인의 이름과 전화번호를 남겨주세요. 추첨을 통해 세 분께 스타벅스 아메리카노를 드립니다 (원하지 않으면 남기시지 않아도 됩니다).
# 0                                    이동석. 01095499548
# 1                                    배준영, 01025546453
# 2                                         01040776968
# 3                                     유현정 01055196640
# 4                                     김서현 01065205259
# 5                                     김하연 01088157041
# 6                                       010 8692 9398
# 7                                     손경화/01099612422
# 8                                   배준수/010-9801-6514
# 9                                     기수빈 01053509508
# 10                         김도현 01066511799  맛있게 먹겠습니다
# ...
